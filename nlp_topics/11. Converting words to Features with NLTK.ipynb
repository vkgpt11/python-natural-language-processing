# %% [markdown]
# # Converting words to Features with NLTK
# compiling feature lists of words from positive reviews and words from the negative reviews to hopefully see trends in specific types of words in positive or negative reviews

# %%
import nltk
import random
from nltk.corpus import movie_reviews

documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

all_words = []

for w in movie_reviews.words():
    all_words.append(w.lower())

all_words = nltk.FreqDist(all_words)

word_features = list(all_words.keys())[:3000]

# %%
word_features[:10]
# Out:
# ['hostility',
#  'kamil',
#  'gangster',
#  'jubilantly',
#  'bailed',
#  'sewing',
#  'aura',
#  'curse',
#  'conelly',
#  'clavell']

# %% [markdown]
# Mostly the same as before, only with now a new variable, word_features, which contains the top 3,000 most common words. Next, we're going to build a quick function that will find these top 3,000 words in our positive and negative documents, marking their presence as either positive or negative:m

# %%
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

# %% [markdown]
# Next, we can print one feature set like:

# %%
print((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
# Out:
# {'hostility': False, 'manhole': False, 'gangster': False, 'jubilantly': False, 'bailed': False, 'sewing': False, 'aura': False, 'bart': False, 'passages': False, 'pantoliano': False, 'spielberg': False, 'damning': False, 'hardass': False, 'olden': False, 'burne': False, 'succeeds': False, 'drills': False, 'journeyed': False, 'moreau': False, 'mentality': False, 'drank': False, 'dariush': False, 'dudeness': False, 'makeover': False, 'cotton': False, 'fletch': False, 'smallest': False, 'editors': False, 'disappeared': False, 'meditation': False, 'abandon': False, 'meanders': False, 'nan': False, 'ignorance': False, 'escorted': False, 'ceaseless': False, 'verge': False, 'elijah': False, 'try': False, 'moaning': False, 'flimsy': False, 'venice': False, 'grumbles': False, 'lightyear': False, 'macalaester': False, 'yevgeny': False, 'lynched': False, 'aciton': False, 'phils': False, 'assedness': False, 'pipelines': False, 'fees': False, 'hills': False, 'week': False, 'complete': False, 'wences': False, 'chereau': False, 'lana': False, 'eigeman': False, 'unexceptional': False, 'mantegna': False, 'chameleon': False, 'bested': False, 'sinbad': False, 'adoptive': False, 'advantaged': False, 'bastardised': False, 'colour': False, 'trimmings': False, 'awesome': False, 'stupefying': False, 'slickster': False, 'defuse': False, 'remeber': False, 'trials': False, '12': False, 'passionately': False, 'ilk': False, 'sunniness': False, 'harp': False, 'urn': False, 'kohn': False, 'yamamoto': False, 'ugliness': False, 'tv': False, 'orange': False, 'multidimensionality': False, 'chechik': False, 'indecent': False, 'beatrice': False, 'smacked': False, '[': False, 'links': False, 'overstated': False, 'ewoks': False, 'journals': False, 'weisz': False, 'seizes': False, 'kennif': False, 'advertisement': False, 'sacrificial': False, 'tulips': False, 'rupaul': False, 'grandma': False, 'ecologist': False, 'maidservant': False, 'rigged': False, 'mobsters': False, 'leguizimo': False, 'preaches': False, 'shallows': False, 'unlistenable': False, 'leaden': False, 'spunky': False, 'stoned': False, 'trolls': False, 'publically': False, 'daisy': False, 'crewmates': False, 'slurring': False, 'organa': False, 'brian': False, 'characteristics': False, 'ninjaman': False, 'thrashing': False, 'fairer': False, 'hairiness': False, 'sampson': False, 'mike': False, 'platoon': False, 'permutation': False, 'devious': False, 'bastille': False, 'yellow': False, 'overplayed': False, 'dreamworld': False, 'amato': False, 'consistently': False, 'juxtaposed': False, 'flippant': False, 'sensations': False, 'bruiser': False, 'drummer': False, 'loverboy': False, 'fonzie': False, 'cliffs': False, 'townfolk': False, 'unexpecting': False, 'persuasion': False, 'cleopatra': False, 'attitude': False, 'unlovable': False, 'shoved': False, 'levying': False, 'guideline': False, 'chinese': False, 'gary': False, 'truth': False, 'starts': True, 'september': False, 'applied': False, 'defeating': False, 'precipice': False, 'efects': False, 'acquittal': False, 'capacity': False, 'rainier': False, 'stray': False, 'inception': False, 'durable': False, 'jolly': False, 'disserve': False, 'hoppy': False, 'transform': False, 'murron': False, 'warmup': False, 'sailors': False, 'discretion': False, 'injection': False, 'duke': False, 'clitoris': False, 'renoir': False, 'slate': False, 'punchline': False, 'confucius': False, 'picket': False, 'lawyers': False, 'hotmail': False, 'gang': False, 'devoting': False, 'mifune': False, 'train': False, 'loni': False, 'transparent': False, 'alphonsia': False, 'dewy': False, 'redirection': False, 'wexler': False, 'alfred': False, 'wit': False, 'gambit': False, 'guttenberg': False, 'gaerity': False, 'necrophilia': False, 'animality': False, 'sentiment': False, 'worldview': False, 'humiliating': False, 'sessions': False, 'outdone': False, 'damone': False, 'patrolman': False, 'trigger': False, 'tannek': False, 'deformation': False, 'miraculous': False, 'unlock': False, 'messy': ...

# %% [markdown]
# Then we can do this for all of our documents, saving the feature existence booleans and their respective positive or negative categories by doing:

# %%
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %%
featuresets[:10]
# Out:
# [({'hostility': False,
#    'manhole': False,
#    'gangster': False,
#    'jubilantly': False,
#    'bailed': False,
#    'sewing': False,
#    'aura': False,
#    'bart': False,
#    'passages': False,
#    'pantoliano': False,
#    'spielberg': False,
#    'damning': False,
#    'hardass': False,
#    'olden': False,
#    'burne': False,
#    'succeeds': False,
#    'drills': False,
#    'journeyed': False,
#    'moreau': False,
#    'mentality': False,
#    'drank': False,
#    'dariush': False,
#    'dudeness': False,
#    'makeover': False,
#    'cotton': False,
#    'fletch': False,
#    'smallest': False,
#    'editors': False,
#    'disappeared': False,
#    'meditation': False,
#    'abandon': False,
#    'meanders': False,
#    'nan': False,
#    'ignorance': False,
#    'escorted': False,
#    'ceaseless': False,
#    'verge': False,
#    'elijah': False,
#    'try': False,
#    'moaning': False,
#    'flimsy': False,
#    'venice': False,
#    'grumbles': False,
#    'lightyear': False,
#    'macalaester': False,
#    'yevgeny': False,
#    'lynched': False,
#    'aciton': False,
#    'phils': False,
#    'assedness': False,
#    'pipelines': False,
#    'fees': False,
#    'hills': False,
#    'week': True,
#    'complete': False,
#    'wences': False,
#    'chereau': False,
#    'lana': False,
#    'eigeman': False,
#    'unexceptional': False,
#    'mantegna': False,
#    'chameleon': False,
#    'bested': False,
#    'sinbad': False,
#    'adoptive': False,
#    'advantaged': False,
#    'bastardised': False,
#    'colour': False,
#    'trimmings': False,
#    'awesome': False,
#    'stupefying': False,
#    'slickster': False,
#    'defuse': False,
#    'remeber': False,
#    'trials': False,
#    '12': False,
#    'passionately': False,
#    'ilk': False,
#    'sunniness': False,
#    'harp': False,
#    'urn': False,
#    'kohn': False,
#    'yamamoto': False,
#    'ugliness': False,
#    'tv': False,
#    'orange': False,
#    'multidimensionality': False,
#    'chechik': False,
#    'indecent': False,
#    'beatrice': False,
#    'smacked': False,
#    '[': False,
#    'links': False,
#    'overstated': False,
#    'ewoks': False,
#    'journals': False,
#    'weisz': False,
#    'seizes': False,
#    'kennif': False,
#    'advertisement': False,
#    'sacrificial': False,
#    'tulips': False,
#    'rupaul': False,
#    'grandma': False,
#    'ecologist': False,
#    'maidservant': False,
#    'rigged': False,
#    'mobsters': False,
#    'leguizimo': False,
#    'preaches': False,
#    'shallows': False,
#    'unlistenable': False,
#    'leaden': False,
#    'spunky': False,
#    'stoned': False,
#    'trolls': False,
#    'publically': False,
#    'daisy': False,
#    'crewmates': False,
#    'slurring': False,
#    'organa': False,
#    'brian': False,
#    'characteristics': False,
#    'ninjaman': False,
#    'thrashing': False,
#    'fairer': False,
#    'hairiness': False,
#    'sampson': False,
#    'mike': False,
#    'platoon': False,
#    'permutation': False,
#    'devious': False,
#    'bastille': False,
#    'yellow': False,
#    'overplayed': False,
#    'dreamworld': False,
#    'amato': False,
#    'consistently': False,
#    'juxtaposed': False,
#    'flippant': False,
#    'sensations': False,
#    'bruiser': False,
#    'drummer': False,
#    'loverboy': False,
#    'fonzie': False,
#    'cliffs': False,
#    'townfolk': False,
#    'unexpecting': False,
#    'persuasion': False,
#    'cleopatra': False,
#    'attitude': False,
#    'unlovable': False,
#    'shoved': False,
#    'levying': False,
#    'guideline': False,
#    'chinese': False,
#    'gary': False,
#    'truth': False,
#    'starts': False,
#    'september': False,
#    'applied': False,
#    'defeating': False,
#    'precipice': False,
#    'efects': False,
#    'acquittal': False,
#    'capacity': False,
#    'rainier': False,
#    'stray': False,
#    'inception': False,
#    'durable': False,
#    'jolly': False,
#    'disserve': False,
#    'hoppy': False,
#    'transform': False,
#    'murron': False,
#    'warmup': False,
#    'sailors': False,
#    'discretion': False,
#    'injection': False,
#    'duke': False,
#    'clitoris': False,
#    'renoir': False,
#    'slate': False,
#    'punchline': False,
#    'confucius': False,
#    'picket': False,
#    'lawyers': False,
#    'hotmail': False,
#    'gang': False,
#    'devoting': False,
#    'mifune': False,
#    'train': False,
#    'loni': False,
#    'transparent': False,
#    'alphonsia': False,
#    'dewy': False,
#    'redirection': False,
#    'wexler': False,
#    'alfred': False,
#    'wit': False,
#    'gambit': False,
#    'guttenberg': False,
#    'gaerity': False,
#    'necrophilia': False,
#    'animality': False,
#    'sentiment': False,
#    'worldview': False,
#    'humiliating': False,
#    'sessions': False,
#    'outdone': False,
#    'damone': False,
#    'patrolman': False,
#    'trigger': False,
#    'tannek': False,
#    'deformation': False,
#    'miraculous': False,
#    'unlock': False,
#    'messy': False,
#    'drawling': False,
#    'tearing': False,
#    'complicated': False,
#    'hails': False,
#    'joes': False,
#    'xer': False,
#    'hanging': False,
#    'retrospection': False,
#    'stravinsky': False,
#    'redeeming': False,
#    'staccatto': False,
#    'ribbons': False,
#    'throes': False,
#    'scolex': False,
#    'saucers': False,
#    'dedication': False,
#    'rocked': False,
#    'lunes': False,
#    'babaloo': False,
#    'griffiths': False,
#    'delude': False,
#    'burglar': False,
#    'parties': False,
#    'defusing': False,
#    'annihilate': False,
#    'contraceptive': False,
#    'sausalito': False,
#    'church': False,
#    'sugary': False,
#    'mutilating': False,
#    'bello': False,
#    'musker': False,
#    'improvements': False,
#    'centerpieces': False,
#    'strangles': False,
#    'lagpacan': False,
#    'finest': False,
#    'curtis': False,
#    'meat': False,
#    'tunes': False,
#    'slapping': False,
#    'foreigners': False,
#    'malay': False,
#    'grossest': False,
#    'illuminate': False,
#    'kershner': False,
#    'spacemusic': False,
#    'defiant': False,
#    '==========================': False,
#    'skyscrapers': False,
#    'guilfoyle': False,
#    'dirtier': False,
#    '82': False,
#    'conscript': False,
#    'capabilities': False,
#    'hunch': False,
#    'magisterial': False,
#    'moisten': False,
#    'insults': False,
#    'madyline': False,
#    'raul': False,
#    'venting': False,
#    'portinari': False,
#    'dispel': False,
#    'ra': False,
#    'eventually': False,
#    'determining': False,
#    '2023': False,
#    'paltry': False,
#    'convent': False,
#    'considers': False,
#    'subtlety': False,
#    'passionate': False,
#    'demented': False,
#    'clanking': False,
#    '80s': False,
#    'grasshoppers': False,
#    'korner': False,
#    'connor': False,
#    'exchanged': False,
#    'flinch': False,
#    'confided': False,
#    'plotholes': False,
#    'indescribable': False,
#    'distances': False,
#    'marsha': False,
#    'hiatus': False,
#    'undefeatable': False,
#    'buren': False,
#    'cavanaugh': False,
#    'tip': False,
#    'liar': False,
#    'enterataining': False,
#    'alter': False,
#    'dominio': False,
#    'gester': False,
#    'lan': False,
#    'cinematographr': False,
#    'purse': False,
#    'doubted': False,
#    'guerrillas': False,
#    'imprisoned': False,
#    'dalliance': False,
#    'mayhem': False,
#    'yuh': False,
#    'sprees': False,
#    'fluent': False,
#    'laughed': False,
#    'concorde': False,
#    'sherrie': False,
#    'topiary': False,
#    'populated': False,
#    'nolot': False,
#    'clunkiness': False,
#    'mccallum': False,
#    'peeking': False,
#    'madeline': False,
#    'bumpkin': False,
#    'differentiated': False,
#    'brother': False,
#    'noir': False,
#    'cycle': False,
#    'widow': False,
#    'pieh': False,
#    'deepti': False,
#    'twitching': False,
#    'nixes': False,
#    'stoically': False,
#    'acknowledgement': False,
#    '60s': False,
#    'videocam': False,
#    'marijuana': False,
#    'caricatured': False,
#    'menahem': False,
#    'negates': False,
#    'losers': False,
#    'extraction': False,
#    'marriageable': False,
#    'necks': False,
#    'add': False,
#    'anyways': False,
#    'coms': False,
#    'aquarium': False,
#    'pulsating': False,
#    'bulb': False,
#    'newsweek': False,
#    'wrongheaded': False,
#    'v': False,
#    'slums': False,
#    'fireplace': False,
#    'edina': False,
#    'mood': False,
#    'rawls': False,
#    'prances': False,
#    'shyer': False,
#    'timoney': False,
#    '26th': False,
#    'dunking': False,
#    'tati': False,
#    'twitches': False,
#    'lousy': False,
#    'propulsion': False,
#    'disturbing': False,
#    'inclement': False,
#    'midknight': False,
#    'wainwright': False,
#    'empathic': False,
#    'immunity': False,
#    'isles': False,
#    'means': False,
#    'lusted': False,
#    'mandala': False,
#    'huffs': False,
#    'unknowingly': False,
#    'couple': False,
#    'stereoscopic': False,
#    'benign': False,
#    'alien': False,
#    'renounced': False,
#    'channeling': False,
#    'historical': False,
#    'messing': False,
#    'ruler': False,
#    'embarrased': False,
#    'deaden': False,
#    'picnic': False,
#    'moonshine': False,
#    'gutenberg': False,
#    'disregards': False,
#    'phenomenon': False,
#    'advocate': False,
#    'condemn': False,
#    'locates': False,
#    'dimensions': False,
#    'hil': False,
#    'constructed': False,
#    'lionizing': False,
#    'sanitises': False,
#    'monstrosity': False,
#    'chuckster': False,
#    'harassed': False,
#    'paths': False,
#    'worrys': False,
#    'liberal': False,
#    'estate': False,
#    'napolean': False,
#    'dunne': False,
#    'perpetrator': False,
#    'deflect': False,
#    'homework': False,
#    'jazzy': False,
#    'unidentifiable': False,
#    'lidner': False,
#    'sufis': False,
#    'compound': False,
#    'negligible': False,
#    'vest': False,
#    'berets': False,
#    'obtuse': False,
#    'pumpkins': False,
#    'conductor': False,
#    'portents': False,
#    'bannister': False,
#    'enamor': False,
#    'ardent': False,
#    'brainchild': False,
#    'photon': False,
#    'toss': False,
#    'partying': False,
#    'willing': False,
#    'spring': False,
#    'shopkeeper': False,
#    'matt': False,
#    'nts': False,
#    'pratfalls': False,
#    'factored': False,
#    'canyon': False,
#    'chilled': False,
#    'hazmat': False,
#    'ailing': False,
#    'igor': False,
#    'lodgerley': False,
#    'gambols': False,
#    'admittedly': False,
#    'leather': False,
#    'cutie': False,
#    'trackers': False,
#    'blurts': False,
#    'debt': False,
#    'rift': False,
#    'downcast': False,
#    'lending': False,
#    'bawdy': False,
#    'bartellemeo': False,
#    'mgm': False,
#    'sung': False,
#    'seduction': False,
#    'heartbroken': False,
#    'photographed': False,
#    'misrepresentation': False,
#    'discouraging': False,
#    'shilling': False,
#    'bartkowiak': False,
#    'recurring': False,
#    'crests': False,
#    'rylance': False,
#    'gaby': False,
#    'falzone': False,
#    'hounded': False,
#    'entertainment': False,
#    '2th': False,
#    'khanh': False,
#    'hodges': False,
#    'skyways': False,
#    'violets': False,
#    'spencer': False,
#    'ap2': False,
#    'dutt': False,
#    'portraying': False,
#    'slowed': False,
#    'murtaugh': False,
#    'alleged': False,
#    'wednesdays': False,
#    'marisa': False,
#    'businessmen': False,
#    'redefines': False,
#    'estella': False,
#    'plan': False,
#    'rapping': False,
#    'cops': False,
#    'parade': False,
#    'utilize': False,
#    'boats': False,
#    'winston': False,
#    'macchio': False,
#    'doffs': False,
#    'bronze': False,
#    'masochism': False,
#    'chew': False,
#    'expand': False,
#    'inhibit': False,
#    'occasionally': False,
#    'supernaturally': False,
#    'stentorian': False,
#    'rhodes': False,
#    'stunts': False,
#    'walsingham': False,
#    'vicious': False,
#    'soderbergh': False,
#    'mith': False,
#    'desintegration': False,
#    'trajectory': False,
#    'turnaround': False,
#    'glasgow': False,
#    'unpopped': False,
#    'mook': False,
#    'intrepid': False,
#    'kyle': False,
#    'winless': False,
#    'equalizes': False,
#    'fares': False,
#    'wall': False,
#    'tightfitting': False,
#    'broadway': False,
#    'milla': False,
#    'constrast': False,
#    'bille': False,
#    'drawbridges': False,
#    'shawnee': False,
#    'pogue': False,
#    'morosely': False,
#    'discarding': False,
#    'reviewed': False,
#    'portia': False,
#    'fabrizio': False,
#    'scaffolding': False,
#    'flashes': False,
#    'nausuem': False,
#    'stops': False,
#    'u2': False,
#    'ratchets': False,
#    'mozell': False,
#    'unsympathetic': False,
#    'tied': False,
#    'mapped': False,
#    'marilyn': False,
#    'cleanest': False,
#    'afflicted': False,
#    'trollop': False,
#    'prevailing': False,
#    '_babe_': False,
#    'fashionable': False,
#    'dishwasher': False,
#    'figgis': False,
#    'infectuous': False,
#    'nears': False,
#    'said': False,
#    'population': False,
#    'cog': False,
#    'muff': False,
#    'affect': False,
#    'kouf': False,
#    'hulce': False,
#    'raeeyain': False,
#    'armstrong': False,
#    'creation': False,
#    'pinnacles': False,
#    'shockingly': False,
#    'projects': False,
#    'defunct': False,
#    'malt': False,
#    'breakdancing': False,
#    'beggining': False,
#    'judd': False,
#    'gadget': False,
#    'inclined': False,
#    'dian': False,
#    'carribean': False,
#    'uses': False,
#    'luftwaffe': False,
#    'jetee': False,
#    'thacker': False,
#    'unearthed': False,
#    'simone': False,
#    'less': False,
#    'saluting': False,
#    'whoah': False,
#    'cleanup': False,
#    'crenna': False,
#    'crystal': False,
#    'bendrix': False,
#    'frederic': False,
#    'pimpernel': False,
#    'idolizing': False,
#    'trapping': False,
#    'parallax': False,
#    'weak': False,
#    'gut': False,
#    'glued': False,
#    'tortures': False,
#    'gish': False,
#    '2017': False,
#    'arrows': False,
#    'draco': False,
#    'variant': False,
#    'medfield': False,
#    'satiric': True,
#    'doormen': False,
#    'lots': False,
#    'unfathomable': False,
#    'plug': False,
#    'catwoman': False,
#    'bloodied': False,
#    'tote': False,
#    'characterisation': False,
#    'valid': False,
#    'tussles': False,
#    'pistone': False,
#    'diggs': False,
#    'shelton': False,
#    'weekly': False,
#    'revenge': False,
#    'authority': False,
#    'surfer': False,
#    'alek': False,
#    'nieces': False,
#    'larger': False,
#    'pollsters': False,
#    'trench': False,
#    'gullette': False,
#    'famke': False,
#    'errand': False,
#    'halloween': False,
#    'guesses': False,
#    'postman': False,
#    'brisville': False,
#    'efforts': False,
#    'overpraised': False,
#    'sidewalk': False,
#    'rehabilitate': False,
#    'stupider': False,
#    'bedpost': False,
#    'comradeship': False,
#    'sounded': False,
#    'stamping': False,
#    'emulating': False,
#    'thai': False,
#    'grier': False,
#    'jars': False,
#    'salaries': False,
#    'supremacy': False,
#    'yugoslavian': False,
#    'ranger': False,
#    'mosley': False,
#    'fluidity': False,
#    'capulet': False,
#    'marg': False,
#    'affiliate': False,
#    'personas': False,
#    'mcconnell': False,
#    'reading': False,
#    'shagadellic': False,
#    'judgements': False,
#    'studying': False,
#    'leblanc': False,
#    'fiddles': False,
#    'bondish': False,
#    'holliday': False,
#    'lenient': False,
#    'poses': False,
#    'upsets': False,
#    'awed': False,
#    'totty': False,
#    'england': False,
#    'winifred': False,
#    '5th': False,
#    'gavan': False,
#    'egypt': False,
#    'callin': False,
#    'outruns': False,
#    'lovestruck': False,
#    'dispatched': False,
#    'indies': False,
#    'rebounding': False,
#    'endorsing': False,
#    'award': False,
#    'lollies': False,
#    'ache': False,
#    'panes': False,
#    'busy': False,
#    'polar': False,
#    'happier': False,
#    'tugging': False,
#    'arguable': False,
#    'stucker': False,
#    'obsesses': False,
#    'vivacious': False,
#    'hoser': False,
#    'beseeches': False,
#    'positions': False,
#    'reads': False,
#    'owes': False,
#    'gofer': False,
#    'keg': False,
#    'magherini': False,
#    'olyphant': False,
#    'workman': False,
#    'closets': False,
#    'cyclic': False,
#    'affiliations': False,
#    'wears': False,
#    'fixes': False,
#    'schwimmer': False,
#    'naboo': False,
#    'haircuts': False,
#    'argonauticus': False,
#    'lensing': False,
#    'mountaintops': False,
#    'pukes': False,
#    'captions': False,
#    'revolutionary': False,
#    'adversaries': False,
#    'pungent': False,
#    'fixing': False,
#    'australia': False,
#    'approachable': False,
#    'sctv': False,
#    'posted': False,
#    'somersets': False,
#    'communicates': False,
#    'fuels': False,
#    'baking': False,
#    'outboard': False,
#    'ejected': False,
#    'investing': False,
#    'immune': False,
#    'focused': False,
#    'skylar': False,
#    'pedophile': False,
#    'mcelhone': False,
#    'christmas': False,
#    'tiepin': False,
#    '1957': False,
#    'poland': False,
#    'volley': False,
#    'costumer': False,
#    'kraft': False,
#    'exuding': False,
#    'laying': False,
#    'feng': False,
#    'cropduster': False,
#    'tomb': False,
#    'stats': False,
#    'bashes': False,
#    'chant': False,
#    'revolutions': False,
#    'mary': False,
#    'prescott': False,
#    'meanings': False,
#    'sodomized': False,
#    'invulnerable': False,
#    'blane': False,
#    'pussyfoot': False,
#    'snorting': False,
#    'bakkers': False,
#    'projectionist': False,
#    'foaming': False,
#    'assorted': False,
#    'replenish': False,
#    'purely': False,
#    'overeager': False,
#    'immortalized': False,
#    'kasa': False,
#    'sarossy': False,
#    'publicised': False,
#    'crowdpleasing': False,
#    'lester': False,
#    'orwellian': False,
#    'calming': False,
#    'ade': False,
#    'outmatches': False,
#    'scot': False,
#    'mechanics': False,
#    'locking': False,
#    'valor': False,
#    'mysore': False,
#    'jousting': False,
#    'baldly': False,
#    'fratboy': False,
#    'commercialize': False,
#    'alliances': False,
#    'fujimoto': False,
#    '2259': False,
#    'uncontrolled': False,
#    'loup': False,
#    'unbroken': False,
#    'commits': False,
#    'crawly': False,
#    'arrests': False,
#    'compromising': False,
#    'chose': False,
#    'has': True,
#    'cheered': False,
#    'periodical': False,
#    'mannered': False,
#    'dispels': False,
#    'obviousness': False,
#    'insensitive': False,
#    'recommendation': False,
#    'ditching': False,
#    'steaminess': False,
#    'kareem': False,
#    'trust': False,
#    'feldman': False,
#    'absorb': False,
#    'jetsons': False,
#    'dances': False,
#    'endless': False,
#    'deciple': False,
#    'furnished': False,
#    'grills': False,
#    'vcrs': False,
#    'booger': False,
#    'yom': False,
#    'growl': False,
#    'vain': False,
#    'chaps': False,
#    'inspired': False,
#    'sincerely': False,
#    'bauble': False,
#    'slater': False,
#    'seeking': False,
#    'copeland': False,
#    'interupts': False,
#    'dignified': False,
#    'knuckleheaded': False,
#    'sexpot': False,
#    'surviving': False,
#    'viability': False,
#    'englund': False,
#    'confirms': False,
#    'girlish': False,
#    'incredulously': False,
#    'oppposed': False,
#    'eyelashes': False,
#    'valet': False,
#    'oblivious': False,
#    'rueland': False,
#    'showed': False,
#    'moralistically': False,
#    'mimicking': False,
#    'housewarming': False,
#    'pirate': False,
#    'scripts': False,
#    'restrictions': False,
#    'aunts': False,
#    'cynthia': False,
#    'woodsboro': False,
#    'behaves': False,
#    'bland': False,
#    'gazers': False,
#    'lessen': False,
#    'fahey': False,
#    'clavell': False,
#    'poles': False,
#    'hypnotises': False,
#    'hallucinogenic': False,
#    'strongman': False,
#    'graziella': False,
#    'freddy': False,
#    'leisure': False,
#    'dallwitz': False,
#    'sites': False,
#    'dissappears': False,
#    'synchronized': False,
#    '_october': False,
#    'morissey': False,
#    'hulking': False,
#    'commericials': False,
#    'thrilled': False,
#    'soulmate': False,
#    'woman': False,
#    'subtitling': False,
#    'build': False,
#    'tag': False,
#    'slew': False,
#    'mocks': False,
#    'bosoms': False,
#    'depp': False,
#    'odd': False,
#    'zigged': False,
#    'mst3k': False,
#    'mocking': False,
#    'yeshiva': False,
#    'spilled': False,
#    'melvin': False,
#    'lot': False,
#    'synapses': False,
#    'terrorized': False,
#    'break': False,
#    'olds': False,
#    'morrissey': False,
#    '59': False,
#    'dork': False,
#    'ranking': False,
#    'routine': False,
#    'accused': False,
#    'halen': False,
#    'tapeheads': False,
#    'dissapointed': False,
#    'unraveled': False,
#    'nexus': False,
#    'argentinian': False,
#    'grandeur': False,
#    'tarkofsky': False,
#    'enlistment': False,
#    'elusive': False,
#    'differences': False,
#    'impossibly': False,
#    'sewer': False,
#    'gourmets': False,
#    'intrusive': False,
#    'traumatic': False,
#    'fex': False,
#    'crackling': False,
#    'sassiness': False,
#    'mitsubishi': False,
#    'mcnaughton': False,
#    'intrinsic': False,
#    'unsuspecting': False,
#    'dilapidating': False,
#    'swears': False,
#    'ethical': False,
#    'ath': False,
#    'e1': False,
#    'heading': False,
#    'undiscerning': False,
#    'unaddressed': False,
#    'pretentious': False,
#    'righteous': False,
#    'owners': False,
#    '13th': False,
#    'arsed': False,
#    'ferrera': False,
#    'turmoil': False,
#    'suong': False,
#    'probes': False,
#    'searing': False,
#    'faber': False,
#    'blended': False,
#    'distributed': False,
#    'exuberant': False,
#    'portions': False,
#    'achilles': False,
#    'charred': False,
#    'ours': False,
#    'quirkier': False,
#    'mintues': False,
#    'noel': False,
#    'gonna': False,
#    'exceptionally': False,
#    'maura': False,
#    'sleepwalk': False,
#    'garnered': False,
#    'wanting': False,
#    'wrecking': False,
#    'broodwarrior': False,
#    'steptoe': False,
#    'climaxes': False,
#    'active': False,
#    'bile': False,
#    'magenta': False,
#    'fatales': False,
#    'koven': False,
#    'driller': False,
#    'feigns': False,
#    'prophesy': False,
#    'muted': False,
#    'carolyn': False,
#    'celluloid': False,
#    'smithees': False,
#    'earthquake': False,
#    ...},
#   'neg'),
#  ({'hostility': False,
#    'manhole': False,
#    'gangster': False,
#    'jubilantly': False,
#    'bailed': False,
#    'sewing': False,
#    'aura': False,
#    'bart': False,
#    'passages': False,
#    'pantoliano': False,
#    'spielberg': False,
#    'damning': False,
#    'hardass': False,
#    'olden': False,
#    'burne': False,
#    'succeeds': False,
#    'drills': False,
#    'journeyed': False,
#    'moreau': False,
#    'mentality': False,
#    'drank': False,
#    'dariush': False,
#    'dudeness': False,
#    'makeover': False,
#    'cotton': False,
#    'fletch': False,
#    'smallest': False,
#    'editors': False,
#    'disappeared': False,
#    'meditation': False,
#    'abandon': False,
#    'meanders': False,
#    'nan': False,
#    'ignorance': False,
#    'escorted': False,
#    'ceaseless': False,
#    'verge': False,
#    'elijah': False,
#    'try': False,
#    'moaning': False,
#    'flimsy': False,
#    'venice': False,
#    'grumbles': False,
#    'lightyear': False,
#    'macalaester': False,
#    'yevgeny': False,
#    'lynched': False,
#    'aciton': False,
#    'phils': False,
#    'assedness': False,
#    'pipelines': False,
#    'fees': False,
#    'hills': False,
#    'week': False,
#    'complete': False,
#    'wences': False,
#    'chereau': False,
#    'lana': False,
#    'eigeman': False,
#    'unexceptional': False,
#    'mantegna': False,
#    'chameleon': False,
#    'bested': False,
#    'sinbad': False,
#    'adoptive': False,
#    'advantaged': False,
#    'bastardised': False,
#    'colour': False,
#    'trimmings': False,
#    'awesome': False,
#    'stupefying': False,
#    'slickster': False,
#    'defuse': False,
#    'remeber': False,
#    'trials': False,
#    '12': False,
#    'passionately': False,
#    'ilk': False,
#    'sunniness': False,
#    'harp': False,
#    'urn': False,
#    'kohn': False,
#    'yamamoto': False,
#    'ugliness': False,
#    'tv': False,
#    'orange': False,
#    'multidimensionality': False,
#    'chechik': False,
#    'indecent': False,
#    'beatrice': False,
#    'smacked': False,
#    '[': False,
#    'links': False,
#    'overstated': False,
#    'ewoks': False,
#    'journals': False,
#    'weisz': False,
#    'seizes': False,
#    'kennif': False,
#    'advertisement': False,
#    'sacrificial': False,
#    'tulips': False,
#    'rupaul': False,
#    'grandma': False,
#    'ecologist': False,
#    'maidservant': False,
#    'rigged': False,
#    'mobsters': False,
#    'leguizimo': False,
#    'preaches': False,
#    'shallows': False,
#    'unlistenable': False,
#    'leaden': False,
#    'spunky': False,
#    'stoned': False,
#    'trolls': False,
#    'publically': False,
#    'daisy': False,
#    'crewmates': False,
#    'slurring': False,
#    'organa': False,
#    'brian': False,
#    'characteristics': False,
#    'ninjaman': False,
#    'thrashing': False,
#    'fairer': False,
#    'hairiness': False,
#    'sampson': False,
#    'mike': False,
#    'platoon': False,
#    'permutation': False,
#    'devious': False,
#    'bastille': False,
#    'yellow': False,
#    'overplayed': True,
#    'dreamworld': False,
#    'amato': False,
#    'consistently': False,
#    'juxtaposed': False,
#    'flippant': False,
#    'sensations': False,
#    'bruiser': False,
#    'drummer': False,
#    'loverboy': False,
#    'fonzie': False,
#    'cliffs': False,
#    'townfolk': False,
#    'unexpecting': False,
#    'persuasion': False,
#    'cleopatra': False,
#    'attitude': False,
#    'unlovable': False,
#    'shoved': False,
#    'levying': False,
#    'guideline': False,
#    'chinese': False,
#    'gary': False,
#    'truth': False,
#    'starts': False,
#    'september': False,
#    'applied': False,
#    'defeating': False,
#    'precipice': False,
#    'efects': False,
#    'acquittal': False,
#    'capacity': False,
#    'rainier': False,
#    'stray': False,
#    'inception': False,
#    'durable': False,
#    'jolly': False,
#    'disserve': False,
#    'hoppy': False,
#    'transform': False,
#    'murron': False,
#    'warmup': False,
#    'sailors': False,
#    'discretion': False,
#    'injection': False,
#    'duke': False,
#    'clitoris': False,
#    'renoir': False,
#    'slate': False,
#    'punchline': False,
#    'confucius': False,
#    'picket': False,
#    'lawyers': False,
#    'hotmail': False,
#    'gang': False,
#    'devoting': False,
#    'mifune': False,
#    'train': False,
#    'loni': False,
#    'transparent': False,
#    'alphonsia': False,
#    'dewy': False,
#    'redirection': False,
#    'wexler': False,
#    'alfred': False,
#    'wit': False,
#    'gambit': False,
#    'guttenberg': False,
#    'gaerity': False,
#    'necrophilia': False,
#    'animality': False,
#    'sentiment': False,
#    'worldview': False,
#    'humiliating': False,
#    'sessions': False,
#    'outdone': False,
#    'damone': False,
#    'patrolman': False,
#    'trigger': False,
#    'tannek': False,
#    'deformation': False,
#    'miraculous': False,
#    'unlock': False,
#    'messy': False,
#    'drawling': False,
#    'tearing': False,
#    'complicated': False,
#    'hails': False,
#    'joes': False,
#    'xer': False,
#    'hanging': False,
#    'retrospection': False,
#    'stravinsky': False,
#    'redeeming': False,
#    'staccatto': False,
#    'ribbons': False,
#    'throes': False,
#    'scolex': False,
#    'saucers': False,
#    'dedication': False,
#    'rocked': False,
#    'lunes': False,
#    'babaloo': False,
#    'griffiths': False,
#    'delude': False,
#    'burglar': False,
#    'parties': False,
#    'defusing': False,
#    'annihilate': False,
#    'contraceptive': False,
#    'sausalito': False,
#    'church': False,
#    'sugary': False,
#    'mutilating': False,
#    'bello': False,
#    'musker': False,
#    'improvements': False,
#    'centerpieces': False,
#    'strangles': False,
#    'lagpacan': False,
#    'finest': False,
#    'curtis': False,
#    'meat': False,
#    'tunes': False,
#    'slapping': False,
#    'foreigners': False,
#    'malay': False,
#    'grossest': False,
#    'illuminate': False,
#    'kershner': False,
#    'spacemusic': False,
#    'defiant': False,
#    '==========================': False,
#    'skyscrapers': False,
#    'guilfoyle': False,
#    'dirtier': False,
#    '82': False,
#    'conscript': False,
#    'capabilities': False,
#    'hunch': False,
#    'magisterial': False,
#    'moisten': False,
#    'insults': False,
#    'madyline': False,
#    'raul': False,
#    'venting': False,
#    'portinari': False,
#    'dispel': False,
#    'ra': False,
#    'eventually': False,
#    'determining': False,
#    '2023': False,
#    'paltry': False,
#    'convent': False,
#    'considers': False,
#    'subtlety': False,
#    'passionate': False,
#    'demented': False,
#    'clanking': False,
#    '80s': False,
#    'grasshoppers': False,
#    'korner': False,
#    'connor': False,
#    'exchanged': False,
#    'flinch': False,
#    'confided': False,
#    'plotholes': False,
#    'indescribable': False,
#    'distances': False,
#    'marsha': False,
#    'hiatus': False,
#    'undefeatable': False,
#    'buren': False,
#    'cavanaugh': False,
#    'tip': False,
#    'liar': False,
#    'enterataining': False,
#    'alter': False,
#    'dominio': False,
#    'gester': False,
#    'lan': False,
#    'cinematographr': False,
#    'purse': False,
#    'doubted': False,
#    'guerrillas': False,
#    'imprisoned': False,
#    'dalliance': False,
#    'mayhem': False,
#    'yuh': False,
#    'sprees': False,
#    'fluent': False,
#    'laughed': False,
#    'concorde': False,
#    'sherrie': False,
#    'topiary': False,
#    'populated': False,
#    'nolot': False,
#    'clunkiness': False,
#    'mccallum': False,
#    'peeking': False,
#    'madeline': False,
#    'bumpkin': False,
#    'differentiated': False,
#    'brother': True,
#    'noir': False,
#    'cycle': False,
#    'widow': False,
#    'pieh': False,
#    'deepti': False,
#    'twitching': False,
#    'nixes': False,
#    'stoically': False,
#    'acknowledgement': False,
#    '60s': False,
#    'videocam': False,
#    'marijuana': False,
#    'caricatured': False,
#    'menahem': False,
#    'negates': False,
#    'losers': False,
#    'extraction': False,
#    'marriageable': False,
#    'necks': False,
#    'add': True,
#    'anyways': False,
#    'coms': False,
#    'aquarium': False,
#    'pulsating': False,
#    'bulb': False,
#    'newsweek': False,
#    'wrongheaded': False,
#    'v': False,
#    'slums': False,
#    'fireplace': False,
#    'edina': False,
#    'mood': False,
#    'rawls': False,
#    'prances': False,
#    'shyer': False,
#    'timoney': False,
#    '26th': False,
#    'dunking': False,
#    'tati': False,
#    'twitches': False,
#    'lousy': False,
#    'propulsion': False,
#    'disturbing': False,
#    'inclement': False,
#    'midknight': False,
#    'wainwright': False,
#    'empathic': False,
#    'immunity': False,
#    'isles': False,
#    'means': False,
#    'lusted': False,
#    'mandala': False,
#    'huffs': False,
#    'unknowingly': False,
#    'couple': False,
#    'stereoscopic': False,
#    'benign': False,
#    'alien': False,
#    'renounced': False,
#    'channeling': False,
#    'historical': False,
#    'messing': False,
#    'ruler': False,
#    'embarrased': False,
#    'deaden': False,
#    'picnic': False,
#    'moonshine': False,
#    'gutenberg': False,
#    'disregards': False,
#    'phenomenon': False,
#    'advocate': False,
#    'condemn': False,
#    'locates': False,
#    'dimensions': False,
#    'hil': False,
#    'constructed': False,
#    'lionizing': False,
#    'sanitises': False,
#    'monstrosity': False,
#    'chuckster': False,
#    'harassed': False,
#    'paths': False,
#    'worrys': False,
#    'liberal': False,
#    'estate': False,
#    'napolean': False,
#    'dunne': False,
#    'perpetrator': False,
#    'deflect': False,
#    'homework': False,
#    'jazzy': False,
#    'unidentifiable': False,
#    'lidner': False,
#    'sufis': False,
#    'compound': False,
#    'negligible': False,
#    'vest': False,
#    'berets': False,
#    'obtuse': False,
#    'pumpkins': False,
#    'conductor': False,
#    'portents': False,
#    'bannister': False,
#    'enamor': False,
#    'ardent': False,
#    'brainchild': False,
#    'photon': False,
#    'toss': False,
#    'partying': False,
#    'willing': False,
#    'spring': False,
#    'shopkeeper': False,
#    'matt': False,
#    'nts': False,
#    'pratfalls': False,
#    'factored': False,
#    'canyon': False,
#    'chilled': False,
#    'hazmat': False,
#    'ailing': False,
#    'igor': False,
#    'lodgerley': False,
#    'gambols': False,
#    'admittedly': False,
#    'leather': False,
#    'cutie': False,
#    'trackers': False,
#    'blurts': False,
#    'debt': False,
#    'rift': False,
#    'downcast': False,
#    'lending': False,
#    'bawdy': False,
#    'bartellemeo': False,
#    'mgm': False,
#    'sung': False,
#    'seduction': False,
#    'heartbroken': False,
#    'photographed': False,
#    'misrepresentation': False,
#    'discouraging': False,
#    'shilling': False,
#    'bartkowiak': False,
#    'recurring': False,
#    'crests': False,
#    'rylance': False,
#    'gaby': False,
#    'falzone': False,
#    'hounded': False,
#    'entertainment': False,
#    '2th': False,
#    'khanh': False,
#    'hodges': False,
#    'skyways': False,
#    'violets': False,
#    'spencer': False,
#    'ap2': False,
#    'dutt': False,
#    'portraying': False,
#    'slowed': False,
#    'murtaugh': False,
#    'alleged': False,
#    'wednesdays': False,
#    'marisa': False,
#    'businessmen': False,
#    'redefines': False,
#    'estella': False,
#    'plan': False,
#    'rapping': False,
#    'cops': False,
#    'parade': False,
#    'utilize': False,
#    'boats': False,
#    'winston': False,
#    'macchio': False,
#    'doffs': False,
#    'bronze': False,
#    'masochism': False,
#    'chew': False,
#    'expand': False,
#    'inhibit': False,
#    'occasionally': False,
#    'supernaturally': False,
#    'stentorian': False,
#    'rhodes': False,
#    'stunts': False,
#    'walsingham': False,
#    'vicious': False,
#    'soderbergh': False,
#    'mith': False,
#    'desintegration': False,
#    'trajectory': False,
#    'turnaround': False,
#    'glasgow': False,
#    'unpopped': False,
#    'mook': False,
#    'intrepid': False,
#    'kyle': False,
#    'winless': False,
#    'equalizes': False,
#    'fares': False,
#    'wall': False,
#    'tightfitting': False,
#    'broadway': False,
#    'milla': False,
#    'constrast': False,
#    'bille': False,
#    'drawbridges': False,
#    'shawnee': False,
#    'pogue': False,
#    'morosely': False,
#    'discarding': False,
#    'reviewed': False,
#    'portia': False,
#    'fabrizio': False,
#    'scaffolding': False,
#    'flashes': False,
#    'nausuem': False,
#    'stops': False,
#    'u2': False,
#    'ratchets': False,
#    'mozell': False,
#    'unsympathetic': False,
#    'tied': False,
#    'mapped': False,
#    'marilyn': False,
#    'cleanest': False,
#    'afflicted': False,
#    'trollop': False,
#    'prevailing': False,
#    '_babe_': False,
#    'fashionable': False,
#    'dishwasher': False,
#    'figgis': False,
#    'infectuous': False,
#    'nears': False,
#    'said': False,
#    'population': True,
#    'cog': False,
#    'muff': False,
#    'affect': False,
#    'kouf': False,
#    'hulce': False,
#    'raeeyain': False,
#    'armstrong': False,
#    'creation': False,
#    'pinnacles': False,
#    'shockingly': False,
#    'projects': False,
#    'defunct': False,
#    'malt': False,
#    'breakdancing': False,
#    'beggining': False,
#    'judd': False,
#    'gadget': False,
#    'inclined': False,
#    'dian': False,
#    'carribean': False,
#    'uses': False,
#    'luftwaffe': False,
#    'jetee': False,
#    'thacker': False,
#    'unearthed': False,
#    'simone': False,
#    'less': False,
#    'saluting': False,
#    'whoah': False,
#    'cleanup': False,
#    'crenna': False,
#    'crystal': False,
#    'bendrix': False,
#    'frederic': False,
#    'pimpernel': False,
#    'idolizing': False,
#    'trapping': False,
#    'parallax': False,
#    'weak': False,
#    'gut': False,
#    'glued': False,
#    'tortures': False,
#    'gish': False,
#    '2017': False,
#    'arrows': False,
#    'draco': False,
#    'variant': False,
#    'medfield': False,
#    'satiric': False,
#    'doormen': False,
#    'lots': False,
#    'unfathomable': False,
#    'plug': False,
#    'catwoman': False,
#    'bloodied': False,
#    'tote': False,
#    'characterisation': False,
#    'valid': False,
#    'tussles': False,
#    'pistone': False,
#    'diggs': False,
#    'shelton': False,
#    'weekly': False,
#    'revenge': False,
#    'authority': False,
#    'surfer': False,
#    'alek': False,
#    'nieces': False,
#    'larger': False,
#    'pollsters': False,
#    'trench': False,
#    'gullette': False,
#    'famke': False,
#    'errand': False,
#    'halloween': False,
#    'guesses': False,
#    'postman': False,
#    'brisville': False,
#    'efforts': False,
#    'overpraised': False,
#    'sidewalk': False,
#    'rehabilitate': False,
#    'stupider': False,
#    'bedpost': False,
#    'comradeship': False,
#    'sounded': False,
#    'stamping': False,
#    'emulating': False,
#    'thai': False,
#    'grier': False,
#    'jars': False,
#    'salaries': False,
#    'supremacy': False,
#    'yugoslavian': False,
#    'ranger': False,
#    'mosley': False,
#    'fluidity': False,
#    'capulet': False,
#    'marg': False,
#    'affiliate': False,
#    'personas': False,
#    'mcconnell': False,
#    'reading': False,
#    'shagadellic': False,
#    'judgements': False,
#    'studying': False,
#    'leblanc': False,
#    'fiddles': False,
#    'bondish': False,
#    'holliday': False,
#    'lenient': False,
#    'poses': False,
#    'upsets': False,
#    'awed': False,
#    'totty': False,
#    'england': False,
#    'winifred': False,
#    '5th': False,
#    'gavan': False,
#    'egypt': False,
#    'callin': False,
#    'outruns': False,
#    'lovestruck': False,
#    'dispatched': False,
#    'indies': False,
#    'rebounding': False,
#    'endorsing': False,
#    'award': False,
#    'lollies': False,
#    'ache': False,
#    'panes': False,
#    'busy': False,
#    'polar': False,
#    'happier': False,
#    'tugging': False,
#    'arguable': False,
#    'stucker': False,
#    'obsesses': False,
#    'vivacious': False,
#    'hoser': False,
#    'beseeches': False,
#    'positions': False,
#    'reads': False,
#    'owes': False,
#    'gofer': False,
#    'keg': False,
#    'magherini': False,
#    'olyphant': False,
#    'workman': False,
#    'closets': False,
#    'cyclic': False,
#    'affiliations': False,
#    'wears': False,
#    'fixes': False,
#    'schwimmer': False,
#    'naboo': False,
#    'haircuts': False,
#    'argonauticus': False,
#    'lensing': False,
#    'mountaintops': False,
#    'pukes': False,
#    'captions': False,
#    'revolutionary': False,
#    'adversaries': False,
#    'pungent': False,
#    'fixing': False,
#    'australia': False,
#    'approachable': False,
#    'sctv': False,
#    'posted': False,
#    'somersets': False,
#    'communicates': False,
#    'fuels': False,
#    'baking': False,
#    'outboard': False,
#    'ejected': False,
#    'investing': False,
#    'immune': False,
#    'focused': False,
#    'skylar': False,
#    'pedophile': False,
#    'mcelhone': False,
#    'christmas': False,
#    'tiepin': False,
#    '1957': False,
#    'poland': False,
#    'volley': False,
#    'costumer': False,
#    'kraft': False,
#    'exuding': False,
#    'laying': False,
#    'feng': False,
#    'cropduster': False,
#    'tomb': False,
#    'stats': False,
#    'bashes': False,
#    'chant': False,
#    'revolutions': False,
#    'mary': False,
#    'prescott': False,
#    'meanings': False,
#    'sodomized': False,
#    'invulnerable': False,
#    'blane': False,
#    'pussyfoot': False,
#    'snorting': False,
#    'bakkers': False,
#    'projectionist': False,
#    'foaming': False,
#    'assorted': False,
#    'replenish': False,
#    'purely': False,
#    'overeager': False,
#    'immortalized': False,
#    'kasa': False,
#    'sarossy': False,
#    'publicised': False,
#    'crowdpleasing': False,
#    'lester': False,
#    'orwellian': False,
#    'calming': False,
#    'ade': False,
#    'outmatches': False,
#    'scot': False,
#    'mechanics': False,
#    'locking': False,
#    'valor': False,
#    'mysore': False,
#    'jousting': False,
#    'baldly': False,
#    'fratboy': False,
#    'commercialize': False,
#    'alliances': False,
#    'fujimoto': False,
#    '2259': False,
#    'uncontrolled': False,
#    'loup': False,
#    'unbroken': False,
#    'commits': False,
#    'crawly': False,
#    'arrests': False,
#    'compromising': False,
#    'chose': False,
#    'has': True,
#    'cheered': False,
#    'periodical': False,
#    'mannered': False,
#    'dispels': False,
#    'obviousness': False,
#    'insensitive': False,
#    'recommendation': False,
#    'ditching': False,
#    'steaminess': False,
#    'kareem': False,
#    'trust': False,
#    'feldman': False,
#    'absorb': False,
#    'jetsons': False,
#    'dances': False,
#    'endless': False,
#    'deciple': False,
#    'furnished': False,
#    'grills': False,
#    'vcrs': False,
#    'booger': False,
#    'yom': False,
#    'growl': False,
#    'vain': False,
#    'chaps': False,
#    'inspired': False,
#    'sincerely': False,
#    'bauble': False,
#    'slater': False,
#    'seeking': False,
#    'copeland': False,
#    'interupts': False,
#    'dignified': False,
#    'knuckleheaded': False,
#    'sexpot': False,
#    'surviving': False,
#    'viability': False,
#    'englund': False,
#    'confirms': False,
#    'girlish': False,
#    'incredulously': False,
#    'oppposed': False,
#    'eyelashes': False,
#    'valet': False,
#    'oblivious': False,
#    'rueland': False,
#    'showed': False,
#    'moralistically': False,
#    'mimicking': False,
#    'housewarming': False,
#    'pirate': False,
#    'scripts': False,
#    'restrictions': False,
#    'aunts': False,
#    'cynthia': False,
#    'woodsboro': False,
#    'behaves': False,
#    'bland': False,
#    'gazers': False,
#    'lessen': False,
#    'fahey': False,
#    'clavell': False,
#    'poles': False,
#    'hypnotises': False,
#    'hallucinogenic': False,
#    'strongman': False,
#    'graziella': False,
#    'freddy': False,
#    'leisure': False,
#    'dallwitz': False,
#    'sites': False,
#    'dissappears': False,
#    'synchronized': False,
#    '_october': False,
#    'morissey': False,
#    'hulking': False,
#    'commericials': False,
#    'thrilled': False,
#    'soulmate': False,
#    'woman': False,
#    'subtitling': False,
#    'build': False,
#    'tag': False,
#    'slew': False,
#    'mocks': False,
#    'bosoms': False,
#    'depp': False,
#    'odd': False,
#    'zigged': False,
#    'mst3k': False,
#    'mocking': False,
#    'yeshiva': False,
#    'spilled': False,
#    'melvin': False,
#    'lot': True,
#    'synapses': False,
#    'terrorized': False,
#    'break': False,
#    'olds': False,
#    'morrissey': False,
#    '59': False,
#    'dork': True,
#    'ranking': False,
#    'routine': False,
#    'accused': False,
#    'halen': False,
#    'tapeheads': False,
#    'dissapointed': False,
#    'unraveled': False,
#    'nexus': False,
#    'argentinian': False,
#    'grandeur': False,
#    'tarkofsky': False,
#    'enlistment': False,
#    'elusive': False,
#    'differences': False,
#    'impossibly': False,
#    'sewer': False,
#    'gourmets': False,
#    'intrusive': False,
#    'traumatic': False,
#    'fex': False,
#    'crackling': False,
#    'sassiness': False,
#    'mitsubishi': False,
#    'mcnaughton': False,
#    'intrinsic': False,
#    'unsuspecting': False,
#    'dilapidating': False,
#    'swears': False,
#    'ethical': False,
#    'ath': False,
#    'e1': False,
#    'heading': True,
#    'undiscerning': False,
#    'unaddressed': False,
#    'pretentious': False,
#    'righteous': False,
#    'owners': False,
#    '13th': False,
#    'arsed': False,
#    'ferrera': False,
#    'turmoil': False,
#    'suong': False,
#    'probes': False,
#    'searing': False,
#    'faber': False,
#    'blended': False,
#    'distributed': False,
#    'exuberant': False,
#    'portions': False,
#    'achilles': False,
#    'charred': False,
#    'ours': False,
#    'quirkier': False,
#    'mintues': False,
#    'noel': False,
#    'gonna': False,
#    'exceptionally': False,
#    'maura': False,
#    'sleepwalk': False,
#    'garnered': False,
#    'wanting': False,
#    'wrecking': False,
#    'broodwarrior': False,
#    'steptoe': False,
#    'climaxes': False,
#    'active': True,
#    'bile': False,
#    'magenta': False,
#    'fatales': False,
#    'koven': False,
#    'driller': False,
#    'feigns': False,
#    'prophesy': False,
#    'muted': False,
#    'carolyn': False,
#    'celluloid': False,
#    'smithees': False,
#    'earthquake': False,
#    ...},
#   'neg'),
#  ({'hostility': False,
#    'manhole': False,
#    'gangster': False,
#    'jubilantly': False,
#    'bailed': False,
#    'sewing': False,
#    'aura': False,
#    'bart': False,
#    'passages': False,
#    'pantoliano': False,
#    'spielberg': False,
#    'damning': False,
#    'hardass': False,
#    'olden': False,
#    'burne': False,
#    'succeeds': False,
#    'drills': False,
#    'journeyed': False,
#    'moreau': False,
#    'mentality': False,
#    'drank': False,
#    'dariush': False,
#    'dudeness': False,
#    'makeover': False,
#    'cotton': False,
#    'fletch': False,
#    'smallest': False,
#    'editors': False,
#    'disappeared': False,
#    'meditation': False,
#    'abandon': False,
#    'meanders': False,
#    'nan': False,
#    'ignorance': False,
#    'escorted': False,
#    'ceaseless': False,
#    'verge': False,
#    'elijah': False,
#    'try': False,
#    'moaning': False,
#    'flimsy': False,
#    'venice': False,
#    'grumbles': False,
#    'lightyear': False,
#    'macalaester': False,
#    'yevgeny': False,
#    'lynched': False,
#    'aciton': False,
#    'phils': False,
#    'assedness': False,
#    'pipelines': False,
#    'fees': False,
#    'hills': False,
#    'week': False,
#    'complete': False,
#    'wences': False,
#    'chereau': False,
#    'lana': False,
#    'eigeman': False,
#    'unexceptional': False,
#    'mantegna': False,
#    'chameleon': False,
#    'bested': False,
#    'sinbad': False,
#    'adoptive': False,
#    'advantaged': False,
#    'bastardised': False,
#    'colour': False,
#    'trimmings': False,
#    'awesome': False,
#    'stupefying': False,
#    'slickster': False,
#    'defuse': False,
#    'remeber': False,
#    'trials': False,
#    '12': False,
#    'passionately': False,
#    'ilk': False,
#    'sunniness': False,
#    'harp': False,
#    'urn': False,
#    'kohn': False,
#    'yamamoto': False,
#    'ugliness': False,
#    'tv': False,
#    'orange': False,
#    'multidimensionality': False,
#    'chechik': False,
#    'indecent': False,
#    'beatrice': False,
#    'smacked': False,
#    '[': False,
#    'links': False,
#    'overstated': False,
#    'ewoks': False,
#    'journals': False,
#    'weisz': False,
#    'seizes': False,
#    'kennif': False,
#    'advertisement': False,
#    'sacrificial': False,
#    'tulips': False,
#    'rupaul': False,
#    'grandma': False,
#    'ecologist': False,
#    'maidservant': False,
#    'rigged': False,
#    'mobsters': False,
#    'leguizimo': False,
#    'preaches': False,
#    'shallows': False,
#    'unlistenable': False,
#    'leaden': False,
#    'spunky': False,
#    'stoned': False,
#    'trolls': False,
#    'publically': False,
#    'daisy': False,
#    'crewmates': False,
#    'slurring': False,
#    'organa': False,
#    'brian': False,
#    'characteristics': False,
#    'ninjaman': False,
#    'thrashing': False,
#    'fairer': False,
#    'hairiness': False,
#    'sampson': False,
#    'mike': False,
#    'platoon': False,
#    'permutation': False,
#    'devious': False,
#    'bastille': False,
#    'yellow': False,
#    'overplayed': False,
#    'dreamworld': False,
#    'amato': False,
#    'consistently': False,
#    'juxtaposed': False,
#    'flippant': False,
#    'sensations': False,
#    'bruiser': False,
#    'drummer': False,
#    'loverboy': False,
#    'fonzie': False,
#    'cliffs': False,
#    'townfolk': False,
#    'unexpecting': False,
#    'persuasion': False,
#    'cleopatra': False,
#    'attitude': False,
#    'unlovable': False,
#    'shoved': False,
#    'levying': False,
#    'guideline': False,
#    'chinese': False,
#    'gary': False,
#    'truth': False,
#    'starts': False,
#    'september': False,
#    'applied': False,
#    'defeating': False,
#    'precipice': False,
#    'efects': False,
#    'acquittal': False,
#    'capacity': False,
#    'rainier': False,
#    'stray': False,
#    'inception': False,
#    'durable': False,
#    'jolly': False,
#    'disserve': False,
#    'hoppy': False,
#    'transform': False,
#    'murron': False,
#    'warmup': False,
#    'sailors': False,
#    'discretion': False,
#    'injection': False,
#    'duke': False,
#    'clitoris': False,
#    'renoir': False,
#    'slate': False,
#    'punchline': False,
#    'confucius': False,
#    'picket': False,
#    'lawyers': False,
#    'hotmail': False,
#    'gang': False,
#    'devoting': False,
#    'mifune': False,
#    'train': False,
#    'loni': False,
#    'transparent': False,
#    'alphonsia': False,
#    'dewy': False,
#    'redirection': False,
#    'wexler': False,
#    'alfred': False,
#    'wit': True,
#    'gambit': False,
#    'guttenberg': False,
#    'gaerity': False,
#    'necrophilia': False,
#    'animality': False,
#    'sentiment': False,
#    'worldview': False,
#    'humiliating': False,
#    'sessions': False,
#    'outdone': False,
#    'damone': False,
#    'patrolman': False,
#    'trigger': False,
#    'tannek': False,
#    'deformation': False,
#    'miraculous': False,
#    'unlock': False,
#    'messy': False,
#    'drawling': False,
#    'tearing': False,
#    'complicated': False,
#    'hails': False,
#    'joes': False,
#    'xer': False,
#    'hanging': False,
#    'retrospection': False,
#    'stravinsky': False,
#    'redeeming': False,
#    'staccatto': False,
#    'ribbons': False,
#    'throes': False,
#    'scolex': False,
#    'saucers': False,
#    'dedication': False,
#    'rocked': False,
#    'lunes': False,
#    'babaloo': False,
#    'griffiths': False,
#    'delude': False,
#    'burglar': False,
#    'parties': False,
#    'defusing': False,
#    'annihilate': False,
# ...
#    'strangles': False,
#    'lagpacan': False,
#    'finest': False,
#    'curtis': False,
#    'meat': False,
#    'tunes': False,
#    'slapping': False,
#    'foreigners': False,
#    'malay': False,
#    'grossest': False,
#    'illuminate': False,
#    'kershner': False,
#    'spacemusic': False,
#    'defiant': False,
#    '==========================': False,
#    'skyscrapers': False,
#    'guilfoyle': False,
#    'dirtier': False,
#    '82': False,
#    'conscript': False,
#    'capabilities': False,
#    'hunch': False,
#    'magisterial': False,
#    'moisten': False,
#    'insults': False,
#    'madyline': False,
#    'raul': False,
#    'venting': False,
#    'portinari': False,
#    'dispel': False,
#    'ra': False,
#    'eventually': False,
#    'determining': False,
#    '2023': False,
#    'paltry': False,
#    'convent': False,
#    'considers': False,
#    'subtlety': False,
#    'passionate': False,
#    'demented': False,
#    'clanking': False,
#    '80s': False,
#    'grasshoppers': False,
#    'korner': False,
#    'connor': False,
#    'exchanged': False,
#    'flinch': False,
#    'confided': False,
#    'plotholes': False,
#    'indescribable': False,
#    'distances': False,
#    'marsha': False,
#    'hiatus': False,
#    'undefeatable': False,
#    'buren': False,
#    'cavanaugh': False,
#    'tip': False,
#    'liar': False,
#    'enterataining': False,
#    'alter': False,
#    'dominio': False,
#    'gester': False,
#    'lan': False,
#    'cinematographr': False,
#    'purse': False,
#    'doubted': False,
#    'guerrillas': False,
#    'imprisoned': False,
#    'dalliance': False,
#    'mayhem': False,
#    'yuh': False,
#    'sprees': False,
#    'fluent': False,
#    'laughed': False,
#    'concorde': False,
#    'sherrie': False,
#    'topiary': False,
#    'populated': False,
#    'nolot': False,
#    'clunkiness': False,
#    'mccallum': False,
#    'peeking': False,
#    'madeline': False,
#    'bumpkin': False,
#    'differentiated': False,
#    'brother': False,
#    'noir': False,
#    'cycle': False,
#    'widow': False,
#    'pieh': False,
#    'deepti': False,
#    'twitching': False,
#    'nixes': False,
#    'stoically': False,
#    'acknowledgement': False,
#    '60s': False,
#    'videocam': False,
#    'marijuana': False,
#    'caricatured': False,
#    'menahem': False,
#    'negates': False,
#    'losers': False,
#    'extraction': False,
#    'marriageable': False,
#    'necks': False,
#    'add': False,
#    'anyways': False,
#    'coms': False,
#    'aquarium': False,
#    'pulsating': False,
#    'bulb': False,
#    'newsweek': False,
#    'wrongheaded': False,
#    'v': False,
#    'slums': False,
#    'fireplace': False,
#    'edina': False,
#    'mood': False,
#    'rawls': False,
#    'prances': False,
#    'shyer': False,
#    'timoney': False,
#    '26th': False,
#    'dunking': False,
#    'tati': False,
#    'twitches': False,
#    'lousy': False,
#    'propulsion': False,
#    'disturbing': False,
#    'inclement': False,
#    'midknight': False,
#    'wainwright': False,
#    'empathic': False,
#    'immunity': False,
#    'isles': False,
#    'means': False,
#    'lusted': False,
#    'mandala': False,
#    'huffs': False,
#    'unknowingly': False,
#    'couple': False,
#    'stereoscopic': False,
#    'benign': False,
#    'alien': False,
#    'renounced': False,
#    'channeling': False,
#    'historical': False,
#    'messing': False,
#    'ruler': False,
#    'embarrased': False,
#    'deaden': False,
#    'picnic': False,
#    'moonshine': False,
#    'gutenberg': False,
#    'disregards': False,
#    'phenomenon': False,
#    'advocate': False,
#    'condemn': False,
#    'locates': False,
#    'dimensions': False,
#    'hil': False,
#    'constructed': False,
#    'lionizing': False,
#    'sanitises': False,
#    'monstrosity': False,
#    'chuckster': False,
#    'harassed': False,
#    'paths': False,
#    'worrys': False,
#    'liberal': False,
#    'estate': False,
#    'napolean': False,
#    'dunne': False,
#    'perpetrator': False,
#    'deflect': False,
#    'homework': False,
#    'jazzy': False,
#    'unidentifiable': False,
#    'lidner': False,
#    'sufis': False,
#    'compound': False,
#    'negligible': False,
#    'vest': False,
#    'berets': False,
#    'obtuse': False,
#    'pumpkins': False,
#    'conductor': False,
#    'portents': False,
#    'bannister': False,
#    'enamor': False,
#    'ardent': False,
#    'brainchild': False,
#    'photon': False,
#    'toss': False,
#    'partying': False,
#    'willing': False,
#    'spring': True,
#    'shopkeeper': False,
#    'matt': False,
#    'nts': False,
#    'pratfalls': False,
#    'factored': False,
#    'canyon': False,
#    'chilled': False,
#    'hazmat': False,
#    'ailing': False,
#    'igor': False,
#    'lodgerley': False,
#    'gambols': False,
#    'admittedly': True,
#    'leather': False,
#    'cutie': False,
#    'trackers': False,
#    'blurts': False,
#    'debt': False,
#    'rift': False,
#    'downcast': False,
#    'lending': False,
#    'bawdy': False,
#    'bartellemeo': False,
#    'mgm': False,
#    'sung': False,
#    'seduction': False,
#    'heartbroken': False,
#    'photographed': False,
#    'misrepresentation': False,
#    'discouraging': False,
#    'shilling': False,
#    'bartkowiak': False,
#    'recurring': False,
#    'crests': False,
#    'rylance': False,
#    'gaby': False,
#    'falzone': False,
#    'hounded': False,
#    'entertainment': False,
#    '2th': False,
#    'khanh': False,
#    'hodges': False,
#    'skyways': False,
#    'violets': False,
#    'spencer': False,
#    'ap2': False,
#    'dutt': False,
#    'portraying': False,
#    'slowed': False,
#    'murtaugh': False,
#    'alleged': False,
#    'wednesdays': False,
#    'marisa': False,
#    'businessmen': False,
#    'redefines': False,
#    'estella': False,
#    'plan': False,
#    'rapping': False,
#    'cops': False,
#    'parade': False,
#    'utilize': False,
#    'boats': False,
#    'winston': False,
#    'macchio': False,
#    'doffs': False,
#    'bronze': False,
#    'masochism': False,
#    'chew': False,
#    'expand': False,
#    'inhibit': False,
#    'occasionally': False,
#    'supernaturally': False,
#    'stentorian': False,
#    'rhodes': False,
#    'stunts': False,
#    'walsingham': False,
#    'vicious': False,
#    'soderbergh': False,
#    'mith': False,
#    'desintegration': False,
#    'trajectory': False,
#    'turnaround': False,
#    'glasgow': False,
#    'unpopped': False,
#    'mook': False,
#    'intrepid': False,
#    'kyle': False,
#    'winless': False,
#    'equalizes': False,
#    'fares': False,
#    'wall': False,
#    'tightfitting': False,
#    'broadway': False,
#    'milla': False,
#    'constrast': False,
#    'bille': False,
#    'drawbridges': False,
#    'shawnee': False,
#    'pogue': False,
#    'morosely': False,
#    'discarding': False,
#    'reviewed': False,
#    'portia': False,
#    'fabrizio': False,
#    'scaffolding': False,
#    'flashes': False,
#    'nausuem': False,
#    'stops': False,
#    'u2': False,
#    'ratchets': False,
#    'mozell': False,
#    'unsympathetic': False,
#    'tied': False,
#    'mapped': False,
#    'marilyn': False,
#    'cleanest': False,
#    'afflicted': False,
#    'trollop': False,
#    'prevailing': False,
#    '_babe_': False,
#    'fashionable': False,
#    'dishwasher': False,
#    'figgis': False,
#    'infectuous': False,
#    'nears': False,
#    'said': True,
#    'population': False,
#    'cog': False,
#    'muff': False,
#    'affect': False,
#    'kouf': False,
#    'hulce': False,
#    'raeeyain': False,
#    'armstrong': False,
#    'creation': False,
#    'pinnacles': False,
#    'shockingly': False,
#    'projects': False,
#    'defunct': False,
#    'malt': False,
#    'breakdancing': False,
#    'beggining': False,
#    'judd': False,
#    'gadget': False,
#    'inclined': False,
#    'dian': False,
#    'carribean': False,
#    'uses': False,
#    'luftwaffe': False,
#    'jetee': False,
#    'thacker': False,
#    'unearthed': False,
#    'simone': False,
#    'less': True,
#    'saluting': False,
#    'whoah': False,
#    'cleanup': False,
#    'crenna': False,
#    'crystal': False,
#    'bendrix': False,
#    'frederic': False,
#    'pimpernel': False,
#    'idolizing': False,
#    'trapping': False,
#    'parallax': False,
#    'weak': False,
#    'gut': False,
#    'glued': False,
#    'tortures': False,
#    'gish': False,
#    '2017': False,
#    'arrows': False,
#    'draco': False,
#    'variant': False,
#    'medfield': False,
#    'satiric': False,
#    'doormen': False,
#    'lots': False,
#    'unfathomable': False,
#    'plug': False,
#    'catwoman': False,
#    'bloodied': False,
#    'tote': False,
#    'characterisation': False,
#    'valid': False,
#    'tussles': False,
#    'pistone': False,
#    'diggs': False,
#    'shelton': False,
#    'weekly': False,
#    'revenge': False,
#    'authority': False,
#    'surfer': False,
#    'alek': False,
#    'nieces': False,
#    'larger': False,
#    'pollsters': False,
#    'trench': False,
#    'gullette': False,
#    'famke': False,
#    'errand': False,
#    'halloween': False,
#    'guesses': False,
#    'postman': False,
#    'brisville': False,
#    'efforts': False,
#    'overpraised': False,
#    'sidewalk': False,
#    'rehabilitate': False,
#    'stupider': False,
#    'bedpost': False,
#    'comradeship': False,
#    'sounded': False,
#    'stamping': False,
#    'emulating': False,
#    'thai': False,
#    'grier': False,
#    'jars': False,
#    'salaries': False,
#    'supremacy': False,
#    'yugoslavian': False,
#    'ranger': False,
#    'mosley': False,
#    'fluidity': False,
#    'capulet': False,
#    'marg': False,
#    'affiliate': False,
#    'personas': False,
#    'mcconnell': False,
#    'reading': False,
#    'shagadellic': False,
#    'judgements': False,
#    'studying': False,
#    'leblanc': False,
#    'fiddles': False,
#    'bondish': False,
#    'holliday': False,
#    'lenient': False,
#    'poses': False,
#    'upsets': False,
#    'awed': False,
#    'totty': False,
#    'england': False,
#    'winifred': False,
#    '5th': False,
#    'gavan': False,
#    'egypt': False,
#    'callin': False,
#    'outruns': False,
#    'lovestruck': False,
#    'dispatched': False,
#    'indies': False,
#    'rebounding': False,
#    'endorsing': False,
#    'award': False,
#    'lollies': False,
#    'ache': False,
#    'panes': False,
#    'busy': False,
#    'polar': False,
#    'happier': False,
#    'tugging': False,
#    'arguable': False,
#    'stucker': False,
#    'obsesses': False,
#    'vivacious': False,
#    'hoser': False,
#    'beseeches': False,
#    'positions': False,
#    'reads': False,
#    'owes': False,
#    'gofer': False,
#    'keg': False,
#    'magherini': False,
#    'olyphant': False,
#    'workman': False,
#    'closets': False,
#    'cyclic': False,
#    'affiliations': False,
#    'wears': False,
#    'fixes': False,
#    'schwimmer': False,
#    'naboo': False,
#    'haircuts': False,
#    'argonauticus': False,
#    'lensing': False,
#    'mountaintops': False,
#    'pukes': False,
#    'captions': False,
#    'revolutionary': False,
#    'adversaries': False,
#    'pungent': False,
#    'fixing': False,
#    'australia': False,
#    'approachable': False,
#    'sctv': False,
#    'posted': False,
#    'somersets': False,
#    'communicates': False,
#    'fuels': False,
#    'baking': False,
#    'outboard': False,
#    'ejected': False,
#    'investing': False,
#    'immune': False,
#    'focused': False,
#    'skylar': False,
#    'pedophile': False,
#    'mcelhone': False,
#    'christmas': False,
#    'tiepin': False,
#    '1957': False,
#    'poland': False,
#    'volley': True,
#    'costumer': False,
#    'kraft': False,
#    'exuding': False,
#    'laying': False,
#    'feng': False,
#    'cropduster': False,
#    'tomb': False,
#    'stats': False,
#    'bashes': False,
#    'chant': False,
#    'revolutions': False,
#    'mary': False,
#    'prescott': False,
#    'meanings': False,
#    'sodomized': False,
#    'invulnerable': False,
#    'blane': False,
#    'pussyfoot': False,
#    'snorting': False,
#    'bakkers': False,
#    'projectionist': False,
#    'foaming': False,
#    'assorted': False,
#    'replenish': False,
#    'purely': False,
#    'overeager': False,
#    'immortalized': True,
#    'kasa': False,
#    'sarossy': False,
#    'publicised': False,
#    'crowdpleasing': False,
#    'lester': False,
#    'orwellian': False,
#    'calming': False,
#    'ade': False,
#    'outmatches': False,
#    'scot': False,
#    'mechanics': False,
#    'locking': False,
#    'valor': False,
#    'mysore': False,
#    'jousting': False,
#    'baldly': False,
#    'fratboy': False,
#    'commercialize': False,
#    'alliances': False,
#    'fujimoto': False,
#    '2259': False,
#    'uncontrolled': False,
#    'loup': False,
#    'unbroken': False,
#    'commits': False,
#    'crawly': False,
#    'arrests': False,
#    'compromising': False,
#    'chose': True,
#    'has': True,
#    'cheered': False,
#    'periodical': False,
#    'mannered': False,
#    'dispels': False,
#    'obviousness': False,
#    'insensitive': False,
#    'recommendation': False,
#    'ditching': False,
#    'steaminess': False,
#    'kareem': False,
#    'trust': False,
#    'feldman': False,
#    'absorb': False,
#    'jetsons': False,
#    'dances': False,
#    'endless': False,
#    'deciple': False,
#    'furnished': False,
#    'grills': False,
#    'vcrs': False,
#    'booger': False,
#    'yom': False,
#    'growl': False,
#    'vain': False,
#    'chaps': False,
#    'inspired': False,
#    'sincerely': False,
#    'bauble': False,
#    'slater': False,
#    'seeking': False,
#    'copeland': False,
#    'interupts': False,
#    'dignified': False,
#    'knuckleheaded': False,
#    'sexpot': False,
#    'surviving': False,
#    'viability': False,
#    'englund': False,
#    'confirms': False,
#    'girlish': False,
#    'incredulously': False,
#    'oppposed': False,
#    'eyelashes': False,
#    'valet': False,
#    'oblivious': False,
#    'rueland': False,
#    'showed': False,
#    'moralistically': False,
#    'mimicking': False,
#    'housewarming': False,
#    'pirate': False,
#    'scripts': False,
#    'restrictions': False,
#    'aunts': False,
#    'cynthia': False,
#    'woodsboro': False,
#    'behaves': False,
#    'bland': False,
#    'gazers': False,
#    'lessen': False,
#    'fahey': False,
#    'clavell': False,
#    'poles': False,
#    'hypnotises': False,
#    'hallucinogenic': False,
#    'strongman': False,
#    'graziella': False,
#    'freddy': False,
#    'leisure': False,
#    'dallwitz': False,
#    'sites': False,
#    'dissappears': False,
#    'synchronized': False,
#    '_october': False,
#    'morissey': False,
#    'hulking': False,
#    'commericials': False,
#    'thrilled': False,
#    'soulmate': False,
#    'woman': False,
#    'subtitling': False,
#    'build': False,
#    'tag': False,
#    'slew': False,
#    'mocks': False,
#    'bosoms': False,
#    'depp': False,
#    'odd': False,
#    'zigged': False,
#    'mst3k': False,
#    'mocking': False,
#    'yeshiva': False,
#    'spilled': False,
#    'melvin': False,
#    'lot': True,
#    'synapses': False,
#    'terrorized': False,
#    'break': False,
#    'olds': False,
#    'morrissey': False,
#    '59': False,
#    'dork': False,
#    'ranking': False,
#    'routine': False,
#    'accused': False,
#    'halen': False,
#    'tapeheads': False,
#    'dissapointed': False,
#    'unraveled': False,
#    'nexus': False,
#    'argentinian': False,
#    'grandeur': False,
#    'tarkofsky': False,
#    'enlistment': False,
#    'elusive': False,
#    'differences': False,
#    'impossibly': False,
#    'sewer': False,
#    'gourmets': False,
#    'intrusive': False,
#    'traumatic': False,
#    'fex': False,
#    'crackling': False,
#    'sassiness': True,
#    'mitsubishi': False,
#    'mcnaughton': False,
#    'intrinsic': False,
#    'unsuspecting': False,
#    'dilapidating': False,
#    'swears': False,
#    'ethical': False,
#    'ath': False,
#    'e1': False,
#    'heading': False,
#    'undiscerning': False,
#    'unaddressed': False,
#    'pretentious': False,
#    'righteous': False,
#    'owners': False,
#    '13th': False,
#    'arsed': False,
#    'ferrera': False,
#    'turmoil': False,
#    'suong': False,
#    'probes': False,
#    'searing': False,
#    'faber': False,
#    'blended': False,
#    'distributed': False,
#    'exuberant': False,
#    'portions': True,
#    'achilles': False,
#    'charred': False,
#    'ours': False,
#    'quirkier': False,
#    'mintues': False,
#    'noel': False,
#    'gonna': False,
#    'exceptionally': False,
#    'maura': False,
#    'sleepwalk': False,
#    'garnered': False,
#    'wanting': False,
#    'wrecking': False,
#    'broodwarrior': False,
#    'steptoe': False,
#    'climaxes': False,
#    'active': False,
#    'bile': False,
#    'magenta': False,
#    'fatales': False,
#    'koven': False,
#    'driller': False,
#    'feigns': False,
#    'prophesy': False,
#    'muted': False,
#    'carolyn': False,
#    'celluloid': False,
#    'smithees': False,
#    'earthquake': False,
#    ...},
#   'neg')]

# %% [markdown]
# Awesome, now that we have our features and labels

# %%
type(featuresets)
# Out:
# list

# %%
len(featuresets)
# Out:
# 2000
